# %% [markdown]
# # ALUNOS:
# - Carlos Eduardo da Silva -- RA: 2328062
# - Alexandre Rosas Costa -- RA: 2326795

# %% [markdown]
# # ANÁLISE EXPLORATÓRIA DE DADOS
#
# ## Etapas: Entendimento do problema, Tratamento dos Dados, Visualização dos dados e Análise Exploratória dos Dados
#
#
# ## Características principais:
# - Date: A data dos dados de preço das ações.
# - Open: O preço de abertura da ação nessa data.
# - High: O maior preço que a ação atingiu durante o pregão.
# - Low: O menor preço que a ação atingiu durante o pregão.
# - Close: O preço de fechamento da ação nessa data.
# - Volume: O volume de negociação, ou seja, o número de ações negociadas naquela data.
# - Dividends: Dividendos pagos nessa data (se houver).
# - Stock Splits: Informações sobre desdobramentos de ações (se houver).
# - Brand_Name: O nome da marca ou empresa.
# - Ticker: Símbolo de ticker para a ação.
# - Industry_Tag: A ca
# egoria de indústria ou setor ao qual a marca pertence.
# - Country: O país onde a marca está sediada ou opera principalmente.
#
# ## Análises potenciais da base
#
# - Análise do Mercado de Ações: Analisar os preços históricos das ações para identificar tendências e padrões no mercado de ações.
# - Brand Performance: Avalie o desempenho de várias marcas no mercado de ações ao longo do tempo.
# - Estratégias de Investimento: Desenvolver estratégias de investimento com base em dados históricos de ações de marcas específicas.
# - Análise Setorial: Explore como diferentes indústrias ou setores estão se comportando no mercado de ações.
# - Comparação entre países: Compare o desempenho das ações das marcas em diferentes países.
# - Análise de Sentimento de Mercado: Analise os movimentos dos preços das ações em relação a notícias ou eventos que afetam marcas ou setores específicos.
#
# ## Escolha um tipo de Análise e realize a Análise Exploratória de acordo com o DataSet selecionado

# %% [markdown]
# # Qual foi a Análise escolhida?
# Resposta: Análise do Mercado de Ações

# %% [markdown]
# # Importar e visualizar a base

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importar a base de dados
df = pd.read_csv('./World-Stock-Prices-Dataset.csv')

# %%
# Visualizar os 4 primeiras linhas da base
df.head(4)
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2023-09-20 00:00:00-04:00    4.840000    4.910000    4.630000    4.670000
# 1  2023-09-20 00:00:00-04:00  397.049988  397.989990  386.119995  386.299988
# 2  2023-09-20 00:00:00-04:00  564.349976  569.219971  562.659973  563.830017
# 3  2023-09-20 00:00:00-04:00  138.550003  139.369995  135.199997  135.289993
#
#        Volume  Dividends  Stock Splits Brand_Name Ticker   Industry_Tag  \
# 0   7441900.0        0.0           0.0    peloton   PTON        fitness
# 1   3866600.0        0.0           0.0    netflix   NFLX  entertainment
# 2   1311500.0        0.0           0.0     costco   COST         retail
# 3  46263700.0        0.0           0.0     amazon   AMZN     e-commerce
#
#   Country
# 0     usa
# 1     usa
# 2     usa
# 3     usa

# %%
# Visualizar os 4 últimas linhas da base
df.tail(4)
# Out:
#                              Date       Open       High        Low      Close  \
# 279749  2023-08-30 00:00:00-04:00  18.180000  18.650000  17.879999  18.549999
# 279750  2023-08-31 00:00:00-04:00  18.620001  19.850000  18.469999  19.620001
# 279751  2023-09-01 00:00:00-04:00  19.660000  20.139999  19.400000  19.870001
# 279752  2023-09-05 00:00:00-04:00  19.730000  19.930000  18.820000  18.840000
#
#            Volume  Dividends  Stock Splits   Brand_Name Ticker Industry_Tag  \
# 279749  5829500.0        0.0           0.0  foot locker     FL     footwear
# 279750  6316100.0        0.0           0.0  foot locker     FL     footwear
# 279751  3982400.0        0.0           0.0  foot locker     FL     footwear
# 279752  5862600.0        0.0           0.0  foot locker     FL     footwear
#
#        Country
# 279749     usa
# 279750     usa
# 279751     usa
# 279752     usa

# %%
# Visualizar a quantidade de linhas e colunas da base 
df.shape
# Out:
# (279753, 12)

# %% [markdown]
# ## Visualizando um resumo das informações

# %%
# Verificando o domínio dos dados
print(df.isna().count())
# Out:
# Date            279753
# Open            279753
# High            279753
# Low             279753
# Close           279753
# Volume          279753
# Dividends       279753
# Stock Splits    279753
# Brand_Name      279753
# Ticker          279753
# Industry_Tag    279753
# Country         279753
# dtype: int64

# %%
# Corrigir o domínio do campo Date

# %%
# Contando a quantidade de valores nulos
null_values = df.isnull().sum()
null_values
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# Brand_Name      0
# Ticker          0
# Industry_Tag    0
# Country         0
# dtype: int64

# %%
# Verificando as informações estatísticas da base
stats = df.describe()
stats
# Out:
#                 Open           High            Low          Close  \
# count  279753.000000  279753.000000  279753.000000  279753.000000
# mean       65.162445      65.914283      64.389596      65.167955
# std       117.203158     118.573147     115.772027     117.190963
# min         0.196890       0.199922       0.192798       0.198861
# 25%        15.049936      15.253301      14.837500      15.050000
# 50%        32.329837      32.712338      31.923977      32.330002
# 75%        72.318681      72.980003      71.635438      72.348923
# max      2165.010010    2175.010010    2138.050049    2153.199951
#
#              Volume      Dividends   Stock Splits
# count  2.797530e+05  279753.000000  279753.000000
# mean   2.349103e+07       0.003406       0.000751
# std    8.864361e+07       0.062041       0.073979
# min    0.000000e+00       0.000000       0.000000
# 25%    1.350600e+06       0.000000       0.000000
# 50%    4.630800e+06       0.000000       0.000000
# ...

# %% [markdown]
# A cardinalidade nos ajuda a saber a quantidade de dados distintos em uma coluna
#
# Se tivermos muitos valores distintos, provavelmente aquela coluna não será uma boa opção para usarmos no modelo
# Matematicamente, cardinalidade é o número de elementos de um conjunto
# Podemos verificar a cardinalidade usando o .nunique()

# %%
# Verificando a cardinalidade da base
card = df.nunique()
card
# Out:
# Date              5966
# Open            245477
# High            247085
# Low             246968
# Close           227083
# Volume          157209
# Dividends          443
# Stock Splits        17
# Brand_Name          61
# Ticker              61
# Industry_Tag        23
# Country              7
# dtype: int64

# %% [markdown]
# ## Visualizando de forma gráfica

# %%
# Visualizando a informação da cardinalidade de forma gráfica (eixo X = índice e eixo Y = cardinalidade )
plt.figure(figsize = (12,6))
plt.bar(card.index, card.values)
plt.xticks(rotation = 90)
plt.xlabel('Índices')
plt.ylabel('Cardinalidades')
plt.title('Informações Cardinais')
plt.show()

# %%
# Visualizando a informação anterior de forma gráfica em ordem decrescente

card = card.sort_values(ascending = False)

plt.figure(figsize = (12,6))
plt.bar(card.index, card.values)
plt.xticks(rotation = 90)
plt.xlabel('Índices')
plt.ylabel('Cardinalidades')
plt.title('Informações Cardinais Descrescente')
plt.show()

# %%
# Verificando o histograma do volume negociado por país 

volume_by_country = df.groupby('Country')['Volume'].sum()

countrys = df['Country'].unique()

# Criar subplots para os histogramas
fig, axs = plt.subplots(len(countrys), figsize=(10, 8))

# Criar um histograma para cada país
for i, country in enumerate(countrys):
    data_country = df[df['Country'] == country]
    axs[i].hist(data_country['Volume'], bins=30, color='blue', alpha=0.7)
    axs[i].set_title(f'Histograma do Volume Negociado em {country}', fontweight = 'bold')
    axs[i].set_xlabel('Volume Negociado')
    axs[i].set_ylabel('Frequência')
    axs[i].grid(True)

plt.tight_layout()
plt.show()

# %%
# Verificando o histograma do volume negociado por país apenas para os 8 maiores volumes de negociação por país

# Encontre os 8 países com os maiores volumes de negociação
top_eight = df.groupby('Country')['Volume'].sum().nlargest().index

# Crie subplots para os histogramas
fig, axs = plt.subplots(len(top_eight), figsize = (10, 10), gridspec_kw={'hspace': 3})


#Crie um histograma para cada um dos 8 países com os maiores volumes
for i, country in enumerate(top_eight):
    data_country = df[df['Country'] == country]
    axs[i].hist(data_country['Volume'], bins=30, color='blue', alpha=0.7)
    axs[i].set_title(f'Histograma do Volume Negociado em {country}', fontweight = 'bold')
    axs[i].set_xlabel('Volume Negociado')
    axs[i].set_ylabel('Frequência')
    axs[i].grid(True)

# %% [markdown]
# ## O boxplot
# - Permite visualizar os percentis e valores máximo e mínimo dos dados
# - Permite visualizar, além de simetria e dispersão dos dados, valores extremos (outliers)
# - O valor máximo e mínimo são calculados baseado no interquartil

# %%
# Verificando para a coluna Volume

plt.figure(figsize = (10, 6))
sns.boxplot(data = df, x = 'Volume', color = 'blue')
plt.title('Distribuição de Valores da Coluna Volume')
plt.xlabel('Valor')
plt.grid(True)
plt.show()

# %%
# Criando o boxplot para as colunas Open e Close 

plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['Open', 'Close']], orient='v', palette='Set2')
plt.title('Boxplot de Preço de Abertura e Fechamento')
plt.ylabel('Preço')
plt.grid(True)
plt.show()

# %%
# Criando o boxplot para as colunas Low e High 

plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['Low', 'High']], orient='v', palette='Set2')
plt.title('Boxplot de Preço Altos e Baixos')
plt.ylabel('Preço')
plt.grid(True)
plt.show()

# %%
# Determinando o interquartil

volume = df['Volume']

#calculando o primeiro quartil
q1 = volume.quantile(0.25)


#calculando o terceiro quartil
q3 = volume.quantile(0.75)

#calculando o iqr
iqr = q3 - q1

iqr
# Out:
# 11033000.0

# %%
# Calculando o valor máximo e mínimo
volume = df['Volume']

#calculando o primeiro quartil
q1 = volume.quantile(0.25)


#calculando o terceiro quartil
q3 = volume.quantile(0.75)

#calculando o iqr
iqr = q3 - q1

#calculando o limite inferior do intervalo de confiança (LIMITE INFERIOR)
min_value = q1 - 1.5 * iqr

#calculando o limite superior do intervalo de confiança (LIMITE SUPERIOR)
max_value = q3 + 1.5 * iqr 

print(f'Valor Mínimo: {min_value}')
print(f'Valor Máximo: {max_value}')
# Out:
# Valor Mínimo: -15198900.0
# Valor Máximo: 28933100.0

# %%
# Verificando a quantidade de registros em cada intervalo (<Q1, entre Q1 e Q2, entre Q2 e Q3,>Q3)

volume = df['Volume']

#calculando o primeiro quartil
q1 = volume.quantile(0.25)


#calculando o terceiro quartil
q3 = volume.quantile(0.75)

# Definindo os limites dos intervalos
inf_limit = q1
sup_limit = q3

# Filtrando os registros em cada intervalo
register_inf_q1 = df[df['Volume'] < inf_limit]
register_bet_q1_q3 = df[(df['Volume'] >= inf_limit) & (df['Volume'] <= sup_limit)]
register_sup_q3 = df[df['Volume'] > sup_limit]

# Contando os registros em cada intervalo
amount_inf_q1 = len(register_inf_q1)
amount_bet_q1_q3 = len(register_bet_q1_q3)
amount_sup_to_q3 = len(register_sup_q3)

print(f'Quantidade de registros abaixo de Q1: {amount_inf_q1}')
print(f'Quantidade de registros no intervalo [Q1, Q3]: {amount_bet_q1_q3}')
print(f'Quantidade de registros acima de Q3: {amount_sup_to_q3}')
# Out:
# Quantidade de registros abaixo de Q1: 69938
# Quantidade de registros no intervalo [Q1, Q3]: 139877
# Quantidade de registros acima de Q3: 69938

# %%
# Verificando para as colunas Open e Close
open_prices = df['Open']
close_prices = df['Close']

# Calculando os quartis para 'Open'
q1_open = open_prices.quantile(0.25)
q3_open = open_prices.quantile(0.75)

# Calculando os quartis para 'Close'
q1_close = close_prices.quantile(0.25)
q3_close = close_prices.quantile(0.75)

# Definindo os limites dos intervalos para 'Open'
inf_limit_open = q1_open
sup_limit_open = q3_open

# Filtrando os registros em cada intervalo para 'Open'
inf_limit_close = q1_close
sup_limit_close = q3_close

# Filtrando os registros em cada intervalo para 'Open'
register_inf_q1_open = df[df['Open'] < inf_limit_open]
register_bet_q1_q3_open = df[(df['Open'] >= inf_limit_open) & (df['Open'] < sup_limit_open)]
register_sup_q3_open = df[df['Open'] > sup_limit_open]

# Filtrando os registros em cada intervalo para 'Close'
register_inf_q1_close = df[df['Close'] < inf_limit_close]
register_bet_q1_q3_close = df[(df['Close'] >= inf_limit_close) & (df['Close'] < sup_limit_close)]
register_sup_q3_close = df[df['Close'] > sup_limit_close]

# Contando os registros em cada intervalo para 'Open'
amount_inf_q1_open = len(register_inf_q1_open)
amount_bet_q1_q3_open = len(register_bet_q1_q3_open)
amount_sup_q3_open = len(register_sup_q3_open)

# Contando os registros em cada intervalo para 'Close'
amount_inf_q1_close = len(register_inf_q1_close)
amount_bet_q1_q3_close = len(register_bet_q1_q3_close)
amount_sup_q3_close = len(register_sup_q3_close)

print(f'Quantidade de registros abaixo de Q1 para Open: {amount_inf_q1_open}')
print(f'Quantidade de registros entre Q1 e Q3 para Open: {amount_bet_q1_q3_open}')
print(f'Quantidade de registros acima de Q3 para Open: {amount_sup_q3_open}')

print(f'Quantidade de registros abaixo de Q1 para Close: {amount_inf_q1_close}')
print(f'Quantidade de registros entre Q1 e Q3 para Close: {amount_bet_q1_q3_close}')
print(f'Quantidade de registros acima de Q3 para Close: {amount_sup_q3_close}')
# Out:
# Quantidade de registros abaixo de Q1 para Open: 69938
# Quantidade de registros entre Q1 e Q3 para Open: 139876
# Quantidade de registros acima de Q3 para Open: 69938
# Quantidade de registros abaixo de Q1 para Close: 69933
# Quantidade de registros entre Q1 e Q3 para Close: 139880
# Quantidade de registros acima de Q3 para Close: 69938

# %% [markdown]
# ## Criando uma matriz para mostrar a correlação de cada par de variáveis**
# - Podemos usar do pandas o `.plotting.scatter_matrix()` ou do seaborn o `.pairplot()`

# %%
# Apresentar a matriz de correção da base

#calculando a matriz de correlação

numeric_columns = ['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']

# Criando um DataFrame apenas com as colunas numéricas
numeric_df = df[numeric_columns]

# Calculando a matriz de correlação para cada par de variáveis
correlation_matrices = {}

for column1 in numeric_columns:
    for column2 in numeric_columns:
        if column1 != column2:
            correlation_matrix = numeric_df[[column1, column2]].corr()
            correlation_matrices[f'{column1} vs {column2}'] = correlation_matrix

# Exibindo as matrizes de correlação para cada par de variáveis
for pair, matrix in correlation_matrices.items():
    print(f'Matriz de Correlação para {pair}:\n{matrix}\n')
# Out:
# Matriz de Correlação para Open vs High:
#           Open      High
# Open  1.000000  0.999911
# High  0.999911  1.000000
#
# Matriz de Correlação para Open vs Low:
#           Open       Low
# Open  1.000000  0.999858
# Low   0.999858  1.000000
#
# Matriz de Correlação para Open vs Close:
#           Open    Close
# Open   1.00000  0.99978
# Close  0.99978  1.00000
#
# Matriz de Correlação para Open vs Volume:
#             Open    Volume
# Open    1.000000 -0.080539
# Volume -0.080539  1.000000
#
# Matriz de Correlação para Open vs Dividends:
#                Open  Dividends
# Open       1.000000   0.017611
# Dividends  0.017611   1.000000
#
# Matriz de Correlação para Open vs Stock Splits:
#                   Open  Stock Splits
# Open          1.000000      0.001836
# Stock Splits  0.001836      1.000000
#
# Matriz de Correlação para High vs Open:
#           High      Open
# High  1.000000  0.999911
# Open  0.999911  1.000000
#
# Matriz de Correlação para High vs Low:
# ...

# %%
# Apresentar a matriz de correlação da base plotando no pairplot

numeric_columns = ['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']

# Criando um DataFrame apenas com as colunas numéricas
numeric_df = df[numeric_columns]

sns.set(style="ticks")
sns.pairplot(numeric_df, kind="scatter")
plt.show()

# %% [markdown]
# ## Visualizando apenas o KDE**
# - KDE: Kernel Density Estimation
#     - Mede a chance de uma variável aleatória assumir determinado valor
#     - A probabilidade é dada pela integral abaixo da curva na faixa de valor selecionada
# - Parece uma "versão de linha suavizada" de um histograma

# %%
# Fazendo o kde do volume negociado por país 

sns.set(style = 'darkgrid')

# Criando um KDE para o volume negociado por país
sns.kdeplot(data=df, x="Volume", hue="Country", fill=True, common_norm=False, palette="tab10")

# Definindo o título e os rótulos dos eixos
plt.title("KDE do Volume Negociado por País")
plt.xlabel("Volume Negociado")
plt.ylabel("Densidade")
plt.show()

# %% [markdown]
# ## Heatmap de correlação

# %%
# Verificando a correlação entre os dados utilizando o heatmap
# Calculando a matriz de correlação
correlation_matrix = df.corr()

plt.figure(figsize=(10, 8))

# Criando um heatmap para a matriz de correlação
sns.heatmap(correlation_matrix, annot=True, cmap='YlGnBu', fmt=".2f", linewidths=0.5)


plt.title('Heatmap de Correlação das Variáveis')
plt.show()
# Out:
# C:\Users\cadua\AppData\Local\Temp\ipykernel_27860\1115569689.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
# Excluir colunas desnecessárias
columns_to_drop = ['Dividends', 'Stock Splits', 'Brand_Name', 'Ticker', 'Industry_Tag']

df = df.drop(columns=columns_to_drop)

# %% [markdown]
# ### Conclusão: identifique quais colunas (variáveis) seriam utilizadas em um modelo de aprendizagem de máquina:
# - Variável de Destino (Target)
# - Variáveis de Recursos (Features)
# - Brand_Name
# - Industry_Tag
# - Country
# - Dividends
# - Stock Splits

# %% [markdown]
# # Pandas Profiling
# https://pypi.org/project/pandas-profiling/

# %%
# Instalar e importar o pandas profiling
from pandas_profiling import ProfileReport

# %%
# Gerando o relatório

data = {
    'Date': ['2023-09-20 00:00:00-04:00', '2023-09-20 00:00:00-04:00', '2023-09-20 00:00:00-04:00', '2023-09-20 00:00:00-04:00'],
    'Open': [4.84, 397.049988, 564.349976, 138.550003],
    'High': [4.91, 397.989990, 569.219971, 139.369995],
    'Low': [4.63, 386.119995, 562.659973, 135.199997],
    'Close': [4.67, 386.299988, 563.830017, 135.289993],
    'Volume': [7441900.0, 3866600.0, 1311500.0, 46263700.0],
    'Dividends': [0.0, 0.0, 0.0, 0.0],
    'Stock Splits': [0.0, 0.0, 0.0, 0.0],
    'Brand_Name': ['peloton', 'netflix', 'costco', 'amazon'],
    'Ticker': ['PTON', 'NFLX', 'COST', 'AMZN'],
    'Industry_Tag': ['fitness', 'entertainment', 'retail', 'e-commerce'],
    'Country': ['usa', 'usa', 'usa', 'usa']
}

# Criar DataFrame
df = pd.DataFrame(data)

# Criar relatório de perfil
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)

# %%
# Visualizar o relatório
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v0.0.dev0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-11-11 19:08:08.242500&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
